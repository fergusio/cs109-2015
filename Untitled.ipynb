# %%
from matplotlib.animation import FuncAnimation
import numpy as np

# for plots, cause visuals

# %matplotlib nbagg

# need fig to pass to the animation function
fig, ax = plt.subplots(figsize=(10, 6))

# fixing the axis size makes sure the animation doesn't jump around as
# matplotlib changes the plot size as data changes
ax.set(xlim=(0, 100), ylim=(0, 300))

x = np.linspace(0,100, 100)
y = np.array([x*i for i in np.linspace(1,3,100)])

line, = ax.plot(x, y[0], color='k', lw=2)

def animate(i):
    line.set_ydata(y[i])

anim = FuncAnimation(
    fig, animate, interval=10, frames=len(x)-1)
 
plt.draw()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
